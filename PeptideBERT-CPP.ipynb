# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/... #edit this path to your PeptideBERT directory
# !pip install -r requirements.txt

# %%
import numpy as np

task_name = 'own_data'

# read data
seqs, labels = [], []
with open('./data/custom_data.csv', 'r') as f:
    for line in f.readlines()[1:]:
        seq, label = line.strip().split(',')
        seqs.append(seq)
        labels.append(int(label))

MAX_LEN = max(map(len, seqs))

# convert to tokens
mapping = dict(zip(
    ['[PAD]','[UNK]','[CLS]','[SEP]','[MASK]','L',
    'A','G','V','E','S','I','K','R','D','T','P','N',
    'Q','F','Y','M','H','C','W'],
    range(30)
))

pos_data, neg_data = [], []
for i in range(len(seqs)):
    seq = [mapping[c] for c in seqs[i]]
    seq.extend([0] * (MAX_LEN - len(seq)))  # padding to max length
    if labels[i] == 1:
        pos_data.append(seq)
    else:
        neg_data.append(seq)

pos_data = np.array(pos_data)
neg_data = np.array(neg_data)

np.savez(
    f'./data/{task_name}-positive.npz',
    arr_0=pos_data
)
np.savez(
    f'./data/{task_name}-negative.npz',
    arr_0=neg_data
)

# %%
# !python data/split_augment.py

# %%
# !python train.py
# Out:
# Device: cuda
#
# ==============================        DATA        ==============================
# Batch size:  32
# Train dataset samples:  297
# Validation dataset samples:  34
# Test dataset samples:  37
# Train dataset batches:  10
# Validation dataset batches:  2
# Test dataset batches:  2
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# pytorch_model.bin: 100% 1.68G/1.68G [00:13<00:00, 122MB/s]
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.15.8
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# ==============================      TRAINING      ==============================
# 100% 10/10 [00:04<00:00,  2.23it/s]
# Epoch 1/50 - Train Loss: 0.7105102658271789	LR: 1e-05
# 100% 2/2 [00:00<00:00, 30.74it/s]
# Epoch 1/50 - Validation Loss: 0.7289851903915405	Validation Accuracy: 61.76470588235294
#
# Model Saved
#
# 100% 10/10 [00:01<00:00,  5.61it/s]
# Epoch 2/50 - Train Loss: 0.6773584306240081	LR: 1e-05
# 100% 2/2 [00:00<00:00, 29.20it/s]
# Epoch 2/50 - Validation Loss: 0.6030779778957367	Validation Accuracy: 41.17647058823529
#
# 100% 10/10 [00:01<00:00,  5.86it/s]
# Epoch 3/50 - Train Loss: 0.6860881507396698	LR: 1e-05
# 100% 2/2 [00:00<00:00, 31.07it/s]
# Epoch 3/50 - Validation Loss: 0.6904855966567993	Validation Accuracy: 64.70588235294117
#
# Model Saved
#
# 100% 10/10 [00:01<00:00,  5.66it/s]
# Epoch 4/50 - Train Loss: 0.6989344596862793	LR: 1e-05
# 100% 2/2 [00:00<00:00, 30.77it/s]
# Epoch 4/50 - Validation Loss: 0.6148080229759216	Validation Accuracy: 50.0
#
# 100% 10/10 [00:01<00:00,  5.84it/s]
# Epoch 5/50 - Train Loss: 0.6714881420135498	LR: 1e-05
# 100% 2/2 [00:00<00:00, 29.28it/s]
# Epoch 5/50 - Validation Loss: 0.6167907118797302	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.84it/s]
# Epoch 6/50 - Train Loss: 0.6590701699256897	LR: 1e-05
# 100% 2/2 [00:00<00:00, 31.25it/s]
# Epoch 6/50 - Validation Loss: 0.6355801224708557	Validation Accuracy: 55.88235294117647
#
# 100% 10/10 [00:01<00:00,  5.69it/s]
# Epoch 7/50 - Train Loss: 0.6861006736755371	LR: 1e-05
# 100% 2/2 [00:00<00:00, 27.50it/s]
# Epoch 7/50 - Validation Loss: 0.5757923424243927	Validation Accuracy: 47.05882352941176
#
# 100% 10/10 [00:01<00:00,  5.60it/s]
# Epoch 8/50 - Train Loss: 0.6745446205139161	LR: 1e-05
# 100% 2/2 [00:00<00:00, 28.49it/s]
# Epoch 8/50 - Validation Loss: 0.5809840857982635	Validation Accuracy: 58.82352941176471
#
# 100% 10/10 [00:01<00:00,  5.72it/s]
# Epoch 9/50 - Train Loss: 0.6539017915725708	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 29.40it/s]
# Epoch 9/50 - Validation Loss: 0.58741694688797	Validation Accuracy: 61.76470588235294
#
# 100% 10/10 [00:01<00:00,  5.78it/s]
# Epoch 10/50 - Train Loss: 0.6442524254322052	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 30.02it/s]
# Epoch 10/50 - Validation Loss: 0.5689438432455063	Validation Accuracy: 55.88235294117647
#
# 100% 10/10 [00:01<00:00,  5.74it/s]
# Epoch 11/50 - Train Loss: 0.6431442201137543	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 31.62it/s]
# Epoch 11/50 - Validation Loss: 0.5591542273759842	Validation Accuracy: 55.88235294117647
#
# 100% 10/10 [00:01<00:00,  5.75it/s]
# Epoch 12/50 - Train Loss: 0.6369636535644532	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 29.94it/s]
# Epoch 12/50 - Validation Loss: 0.5505760610103607	Validation Accuracy: 50.0
#
# 100% 10/10 [00:01<00:00,  5.76it/s]
# Epoch 13/50 - Train Loss: 0.6437758684158326	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 29.99it/s]
# Epoch 13/50 - Validation Loss: 0.5452230721712112	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.72it/s]
# Epoch 14/50 - Train Loss: 0.6349436283111572	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00, 27.21it/s]
# Epoch 14/50 - Validation Loss: 0.5450766235589981	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.71it/s]
# Epoch 15/50 - Train Loss: 0.6437421679496765	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00, 24.85it/s]
# Epoch 15/50 - Validation Loss: 0.545022115111351	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.70it/s]
# Epoch 16/50 - Train Loss: 0.6368025660514831	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00, 29.72it/s]
# Epoch 16/50 - Validation Loss: 0.544754147529602	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.71it/s]
# Epoch 17/50 - Train Loss: 0.641885268688202	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00, 30.12it/s]
# Epoch 17/50 - Validation Loss: 0.5445492118597031	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.71it/s]
# Epoch 18/50 - Train Loss: 0.6409532248973846	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00, 29.72it/s]
# Epoch 18/50 - Validation Loss: 0.5448169112205505	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.70it/s]
# Epoch 19/50 - Train Loss: 0.6484080851078033	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 30.07it/s]
# Epoch 19/50 - Validation Loss: 0.54481241106987	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.68it/s]
# Epoch 20/50 - Train Loss: 0.6437274217605591	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 29
Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.54it/s]
# Epoch 40/50 - Train Loss: 0.639530235528946	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 29.79it/s]
# Epoch 40/50 - Validation Loss: 0.5448713302612305	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.52it/s]
# Epoch 41/50 - Train Loss: 0.6352715432643891	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 29.12it/s]
# Epoch 41/50 - Validation Loss: 0.5448511838912964	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.53it/s]
# Epoch 42/50 - Train Loss: 0.6346209466457366	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 29.41it/s]
# Epoch 42/50 - Validation Loss: 0.544847160577774	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.50it/s]
# Epoch 43/50 - Train Loss: 0.6422686338424682	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 24.30it/s]
# Epoch 43/50 - Validation Loss: 0.544850766658783	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.49it/s]
# Epoch 44/50 - Train Loss: 0.6411540031433105	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 23.15it/s]
# Epoch 44/50 - Validation Loss: 0.5449331700801849	Validation Accuracy: 52.94117647058824
#
# 100% 10/10 [00:01<00:00,  5.49it/s]
# Epoch 45/50 - Train Loss: 0.6367374002933502	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 28.25it/s]
# Epoch 45/50 - Validation Loss: 0.5449544489383698	Validation Accuracy: 50.0
#
# 100% 10/10 [00:01<00:00,  5.49it/s]
# Epoch 46/50 - Train Loss: 0.6477484047412873	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 28.16it/s]
# Epoch 46/50 - Validation Loss: 0.5449815690517426	Validation Accuracy: 50.0
#
# 100% 10/10 [00:01<00:00,  5.48it/s]
# Epoch 47/50 - Train Loss: 0.6487538993358613	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 29.01it/s]
# Epoch 47/50 - Validation Loss: 0.5450359880924225	Validation Accuracy: 50.0
#
# 100% 10/10 [00:01<00:00,  5.47it/s]
# Epoch 48/50 - Train Loss: 0.6350165724754333	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 28.36it/s]
# Epoch 48/50 - Validation Loss: 0.5450099855661392	Validation Accuracy: 50.0
#
# 100% 10/10 [00:01<00:00,  5.47it/s]
# Epoch 49/50 - Train Loss: 0.6389093458652496	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 28.60it/s]
# Epoch 49/50 - Validation Loss: 0.5449622869491577	Validation Accuracy: 50.0
#
# 100% 10/10 [00:01<00:00,  5.46it/s]
# Epoch 50/50 - Train Loss: 0.6349542438983917	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 27.80it/s]
# Epoch 50/50 - Validation Loss: 0.5448996424674988	Validation Accuracy: 50.0
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:           lr ███████▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   train_loss █▅▆▇▃▆▅▃▂▁▂▁▁▂▂▂▁▂▁▁▂▂▂▁▁▂▂▁▂▂▂▂▁▁▂▂▂▂▁▁
# wandb: val_accuracy ▇▁█▄▅▃▆▇▅▄▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▅▄▄▄▄
# wandb:     val_loss █▃▇▄▄▂▂▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:           lr 0.0
# wandb:   train_loss 0.63495
# wandb: val_accuracy 50.0
# wandb:     val_loss 0.5449
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/drive/MyDrive/ELVA/CLASIFICADOR/PeptideBERT/PeptideBERT-master/wandb/offline-run-20250528_171028-sgaixoc8
# wandb: Find logs at: ./wandb/offline-run-20250528_171028-sgaixoc8/logs
# 100% 2/2 [00:00<00:00, 18.51it/s]
# Test Accuracy: 48.64864864864865%
