# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/...  #edit this path to your PeptideBERT directory
# !pip install -q -r requirements.txt

# %%
import numpy as np

task_name = 'own_data_RFU_mean'

# read data
seqs, values  = [], []
with open('./data/custom_data_rfu.csv', 'r') as f:
    for line in f.readlines()[1:]:
        seq, label = line.strip().split(',')
        seqs.append(seq)
        values.append(float(label))

mean_val = np.mean(values)
# Discretizar a 0/1
labels = [1 if v >= mean_val else 0 for v in values]
MAX_LEN = max(map(len, seqs))

# convert to tokens
mapping = dict(zip(
    ['[PAD]','[UNK]','[CLS]','[SEP]','[MASK]','L',
    'A','G','V','E','S','I','K','R','D','T','P','N',
    'Q','F','Y','M','H','C','W'],
    range(30)
))

pos_data, neg_data = [], []
for i in range(len(seqs)):
    seq = [mapping[c] for c in seqs[i]]
    seq.extend([0] * (MAX_LEN - len(seq)))  # padding to max length
    if labels[i] == 1:
        pos_data.append(seq)
    else:
        neg_data.append(seq)

pos_data = np.array(pos_data)
neg_data = np.array(neg_data)

np.savez(
    f'./data/{task_name}-positive.npz',
    arr_0=pos_data
)
np.savez(
    f'./data/{task_name}-negative.npz',
    arr_0=neg_data
)

# %%
# !python data/split_augment.py

# %%
# !python train.py
# Out:
# Device: cuda
#
# ==============================        DATA        ==============================
# Batch size:  32
# Train dataset samples:  383
# Validation dataset samples:  43
# Test dataset samples:  48
# Train dataset batches:  12
# Validation dataset batches:  2
# Test dataset batches:  2
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:943: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.15.8
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# ==============================      TRAINING      ==============================
# 100% 12/12 [00:01<00:00,  7.50it/s]
# Epoch 1/50 - Train Loss: 0.6813835899035136	LR: 1e-05
# 100% 2/2 [00:00<00:00, 48.34it/s]
# Epoch 1/50 - Validation Loss: 0.6369358897209167	Validation Accuracy: 67.44186046511628
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.64it/s]
# Epoch 2/50 - Train Loss: 0.5986452351013819	LR: 1e-05
# 100% 2/2 [00:00<00:00, 46.38it/s]
# Epoch 2/50 - Validation Loss: 0.5918475389480591	Validation Accuracy: 67.44186046511628
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.74it/s]
# Epoch 3/50 - Train Loss: 0.5245851228634516	LR: 1e-05
# 100% 2/2 [00:00<00:00, 47.32it/s]
# Epoch 3/50 - Validation Loss: 0.526898980140686	Validation Accuracy: 69.76744186046511
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.46it/s]
# Epoch 4/50 - Train Loss: 0.4448277031381925	LR: 1e-05
# 100% 2/2 [00:00<00:00, 45.93it/s]
# Epoch 4/50 - Validation Loss: 0.44017937779426575	Validation Accuracy: 79.06976744186046
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.70it/s]
# Epoch 5/50 - Train Loss: 0.39067182938257855	LR: 1e-05
# 100% 2/2 [00:00<00:00, 45.78it/s]
# Epoch 5/50 - Validation Loss: 0.533983588218689	Validation Accuracy: 74.4186046511628
#
# 100% 12/12 [00:01<00:00, 10.14it/s]
# Epoch 6/50 - Train Loss: 0.37448353320360184	LR: 1e-05
# 100% 2/2 [00:00<00:00, 47.99it/s]
# Epoch 6/50 - Validation Loss: 0.6510833203792572	Validation Accuracy: 72.09302325581395
#
# 100% 12/12 [00:01<00:00, 10.14it/s]
# Epoch 7/50 - Train Loss: 0.3830433785915375	LR: 1e-05
# 100% 2/2 [00:00<00:00, 51.17it/s]
# Epoch 7/50 - Validation Loss: 0.4998679757118225	Validation Accuracy: 74.4186046511628
#
# 100% 12/12 [00:01<00:00, 10.14it/s]
# Epoch 8/50 - Train Loss: 0.3813377370436986	LR: 1e-05
# 100% 2/2 [00:00<00:00, 48.22it/s]
# Epoch 8/50 - Validation Loss: 0.5034435987472534	Validation Accuracy: 72.09302325581395
#
# 100% 12/12 [00:01<00:00, 10.14it/s]
# Epoch 9/50 - Train Loss: 0.3616790746649106	LR: 1e-05
# 100% 2/2 [00:00<00:00, 35.53it/s]
# Epoch 9/50 - Validation Loss: 0.39927123486995697	Validation Accuracy: 74.4186046511628
#
# 100% 12/12 [00:01<00:00, 10.06it/s]
# Epoch 10/50 - Train Loss: 0.32882918293277424	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 45.71it/s]
# Epoch 10/50 - Validation Loss: 0.3529772013425827	Validation Accuracy: 83.72093023255815
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.91it/s]
# Epoch 11/50 - Train Loss: 0.29941148683428764	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 48.85it/s]
# Epoch 11/50 - Validation Loss: 0.3386864513158798	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.97it/s]
# Epoch 12/50 - Train Loss: 0.3086259178817272	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 49.48it/s]
# Epoch 12/50 - Validation Loss: 0.34644925594329834	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00, 10.06it/s]
# Epoch 13/50 - Train Loss: 0.31406014412641525	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 41.57it/s]
# Epoch 13/50 - Validation Loss: 0.3514164835214615	Validation Accuracy: 83.72093023255815
#
# 100% 12/12 [00:01<00:00, 10.58it/s]
# Epoch 14/50 - Train Loss: 0.30104435607790947	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 50.63it/s]
# Epoch 14/50 - Validation Loss: 0.34525974094867706	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00, 10.16it/s]
# Epoch 15/50 - Train Loss: 0.29973093420267105	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 49.67it/s]
# Epoch 15/50 - Validation Loss: 0.35134831070899963	Validation Accuracy: 83.72093023255815
#
# 100% 12/12 [00:01<00:00, 10.52it/s]
# Epoch 16/50 - Train Loss: 0.3065116914610068	LR: 1.0000000000000002e-06
# 100% 2/2 [00:00<00:00, 51.91it/s]
# Epoch 16/50 - Validation Loss: 0.343241423368454	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00, 10.24it/s]
# Epoch 17/50 - Train Loss: 0.3084375225007534	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00, 49.19it/s]
# Epoch 17/50 - Validation Loss: 0.3440258055925369	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00, 10.25it/s]
# Epoch 18/50 - Train Loss: 0.2925194924076398	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00, 49.46it/s]
# Epoch 18/50 - Validation Loss: 0.34430770576000214	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00, 10.27it/s]
# Epoch 19/50 - Train Loss: 0.29454561943809193	LR: 1.0000000000000002e-07
# 100% 2/2 [00:00<00:00,
Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.66it/s]
# Epoch 38/50 - Train Loss: 0.2958616738518079	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 38.71it/s]
# Epoch 38/50 - Validation Loss: 0.342939168214798	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.74it/s]
# Epoch 39/50 - Train Loss: 0.29067836329340935	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 46.75it/s]
# Epoch 39/50 - Validation Loss: 0.3429895043373108	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.74it/s]
# Epoch 40/50 - Train Loss: 0.29663514470060665	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 40.33it/s]
# Epoch 40/50 - Validation Loss: 0.34286753833293915	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00, 10.07it/s]
# Epoch 41/50 - Train Loss: 0.29553555448849994	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 40.46it/s]
# Epoch 41/50 - Validation Loss: 0.3428172171115875	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.84it/s]
# Epoch 42/50 - Train Loss: 0.30378588289022446	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 47.91it/s]
# Epoch 42/50 - Validation Loss: 0.3429564833641052	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.91it/s]
# Epoch 43/50 - Train Loss: 0.29308082287510234	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 47.96it/s]
# Epoch 43/50 - Validation Loss: 0.3428949862718582	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.99it/s]
# Epoch 44/50 - Train Loss: 0.30223654210567474	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 47.44it/s]
# Epoch 44/50 - Validation Loss: 0.34281450510025024	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.94it/s]
# Epoch 45/50 - Train Loss: 0.2991320652266343	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 47.56it/s]
# Epoch 45/50 - Validation Loss: 0.3427608460187912	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.86it/s]
# Epoch 46/50 - Train Loss: 0.29053062324722606	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 46.42it/s]
# Epoch 46/50 - Validation Loss: 0.3428087532520294	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.87it/s]
# Epoch 47/50 - Train Loss: 0.29352181777358055	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 48.79it/s]
# Epoch 47/50 - Validation Loss: 0.342837393283844	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00, 10.01it/s]
# Epoch 48/50 - Train Loss: 0.2953515599171321	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 41.35it/s]
# Epoch 48/50 - Validation Loss: 0.3429096192121506	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.85it/s]
# Epoch 49/50 - Train Loss: 0.2892174820105235	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 50.13it/s]
# Epoch 49/50 - Validation Loss: 0.34284909069538116	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# 100% 12/12 [00:01<00:00,  9.97it/s]
# Epoch 50/50 - Train Loss: 0.29723629727959633	LR: 1.0000000000000004e-08
# 100% 2/2 [00:00<00:00, 45.97it/s]
# Epoch 50/50 - Validation Loss: 0.3427405506372452	Validation Accuracy: 86.04651162790698
#
# Model Saved
#
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:           lr ████████▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:   train_loss █▇▅▄▃▃▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: val_accuracy ▁▁▂▅▃▄▃▄██▇█████████████████████████████
# wandb:     val_loss █▇▅▃█▅▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:           lr 0.0
# wandb:   train_loss 0.29724
# wandb: val_accuracy 86.04651
# wandb:     val_loss 0.34274
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/drive/MyDrive/ELVA/CLASIFICADOR/PeptideBERT/PeptideBERT-master/wandb/offline-run-20250531_150751-rlg0366d
# wandb: Find logs at: ./wandb/offline-run-20250531_150751-rlg0366d/logs
# 100% 2/2 [00:00<00:00, 34.03it/s]
# Test Accuracy: 81.25%
# Test Recall: 0.9
# Test Precision: 0.72
# Test F1 Score: 0.7999999999999999
# Test Confusion Matrix:
# [[21  7]
#  [ 2 18]]
